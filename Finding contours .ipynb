# %%
import cv2 
import numpy 
import matplotlib.pyplot as plt

# %%
img=cv2.imread('images/shapes.png',0)
ret,thresh=cv2.threshold(img,127,255,0)
contours,hierachy= cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)#Finding contours

# %%
for contour in contours : 
    print(contour.shape)
# Out:
# (24, 1, 2)
# (134, 1, 2)
# (146, 1, 2)
# (17, 1, 2)
# (117, 1, 2)
# (4, 1, 2)

# %%
# draw first contour
bgr_image = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
cv2.polylines(bgr_image, [contours[0]], True, (0,0,255), 5)
plt.imshow(bgr_image[...,::-1])

# %%
# draw last contour
cv2.polylines(bgr_image, [contours[-1]], True, (0,255,0), 5)
plt.imshow(bgr_image[...,::-1])

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('images/shapes.png', 0)
ret, thresh = cv2.threshold(image, 127, 255, 0)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

bgr_image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)


all_contours = cv2.drawContours(bgr_image, contours, -1, (0,255,0), 3)
plt.imshow(all_contours)

# %%
# Out:
# cv2.CHAIN_APPROX_NONE:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 10
#       7 contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
#       9 print("cv2.CHAIN_APPROX_NONE:")
# ---> 10 print("contours[0].shape: {} so number of points for the contour: {}".format(contours[0].shape, len(contours[0])))
#      12 bgr_image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
#      13 for point in contours[0]:
#
# IndexError: tuple index out of range
